# %% [markdown]
# <a href="https://colab.research.google.com/github/walquiria16/Docker/blob/main/BrazilElectionipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #análise de dados de tendência eleitoral no Brasil
# #data analytics from Brazil election
# #install database

# %%
# !pip install basedosdados
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #import database
# #import pandas
#
# Import the database on the site database/election surveys, pick up a copy of the python code made available by 360, open a project in the big query (google) replace the ID with the project ID created (in this case, database election)

# %%
import basedosdados as bd
import pandas as pd

# Loading data base
import basedosdados as bd

# To load the data directly into the pandas
df = bd.read_table(dataset_id='br_poder360_pesquisas',
table_id='microdados',
billing_project_id="databaelection")

 #The function possibly Visualization the database
df.head()
# Out:
# ...
# Downloading: 100%|██████████| 158195/158195 [00:36<00:00, 4347.72rows/s]
#   id_pesquisa   ano sigla_uf nome_municipio       cargo        data  \
# 0        8023  2006     None           None  presidente  2006-09-19
# 1        8023  2006     None           None  presidente  2006-09-19
# 2        8023  2006     None           None  presidente  2006-09-19
# 3        8023  2006     None           None  presidente  2006-09-19
# 4        8023  2006     None           None  presidente  2006-09-19
#
#   data_referencia  instituto contratante orgao_registro  ...        tipo  \
# 0    18-19.set.06  Datafolha        None           None  ...  estimulada
# 1    18-19.set.06  Datafolha        None           None  ...  estimulada
# 2    18-19.set.06  Datafolha        None           None  ...  estimulada
# 3    18-19.set.06  Datafolha        None           None  ...  estimulada
# 4    18-19.set.06  Datafolha        None           None  ...  estimulada
#
# ...

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
#
# [db.info()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158195 entries, 0 to 158194
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id_pesquisa             158195 non-null  object
#  1   ano                     158195 non-null  Int64
#  2   sigla_uf                140433 non-null  object
#  3   nome_municipio          66475 non-null   object
#  4   cargo                   158195 non-null  object
#  5   data                    158195 non-null  dbdate
#  6   data_referencia         158195 non-null  object
#  7   instituto               158195 non-null  object
#  8   contratante             108116 non-null  object
#  9   orgao_registro          119417 non-null  object
#  10  numero_registro         119688 non-null  object
#  11  quantidade_entrevistas  158008 non-null  float64
#  12  margem_mais             158195 non-null  float64
#  13  margem_menos            158195 non-null  float64
# ...

# %% [markdown]
# the research institute, the year 2022, the second round of the two presidential candidates, Lula and Bolsonaro, the stimulated research and the scenario

# %%
eleicao_2022= df[(df.instituto =='Datafolha')
 & (df.ano==2022) & (df.cargo =='presidente') 
 & (df.sigla_uf.isnull()) & (df.tipo=='estimulada') 
 & (df.turno) & ((df.nome_candidato == 'Bolsonaro') | (df.nome_candidato =='Lula')) 
 &  (df.descricao_cenario.str.contains('cenário 1') == True)].sort_values(by="data")
 
eleicao_2022.head()
# Out:
#       id_pesquisa   ano sigla_uf nome_municipio       cargo        data  \
# 51343        9712  2022     None           None  presidente  2021-05-12
# 51342        9712  2022     None           None  presidente  2021-05-12
# 51333        9712  2022     None           None  presidente  2021-05-12
# 51326        9712  2022     None           None  presidente  2021-05-12
# 54267        9722  2022     None           None  presidente  2021-07-08
#
#       data_referencia  instituto        contratante orgao_registro  ...  \
# 51343  11-12.mai.2021  Datafolha               None           None  ...
# 51342  11-12.mai.2021  Datafolha               None           None  ...
# 51333  11-12.mai.2021  Datafolha               None           None  ...
# 51326  11-12.mai.2021  Datafolha               None           None  ...
# 54267    7-8.jul.2021  Datafolha  Folha de S..Paulo           None  ...
#
#              tipo  turno     tipo_voto  id_cenario  \
# ...

# %% [markdown]
# mudar o back end para uma biblioteca de mais visual

# %%
pd.options.plotting.backend= "plotly"

# %%
eleicao_2022.plot(x='data', y='percentual', color='nome_candidato', facet_row='turno')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
